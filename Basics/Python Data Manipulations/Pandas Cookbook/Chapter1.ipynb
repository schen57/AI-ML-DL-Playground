# %% [markdown]
# This dataset is a list of how many people were on 7 different bike paths in Montreal, each day.

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
 #Make the graphs a bit prettier

# %%
broken_df=pd.read_csv("/Users/shengyuchen/Dropbox/Engagement - Business/My Hub/AI:ML:DL Playground/Basics/Python Data Manipulations/Pandas Cookbook/bikes.csv")

# I can't even read the dataset into my thing
# Fortunately there are some levers that we can pull to handle this situation
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-10-06e778158f10> in <module>()
# ----> 1 broken_df=pd.read_csv("/Users/shengyuchen/Dropbox/Engagement - Business/My Hub/AI:ML:DL Playground/Basics/Python Data Manipulations/Pandas Cookbook/bikes.csv")
#
# ...

# %%
# Omg this step is so fucking important
fixed_df=pd.read_csv("/Users/shengyuchen/Dropbox/Engagement - Business/My Hub/AI:ML:DL Playground/Basics/Python Data Manipulations/Pandas Cookbook/bikes.csv",
                    sep=";",encoding="latin1",
                     parse_dates=["Date"],
                     dayfirst=True,index_col="Date")
# Several things are done here to deal with the messiness of this data
#1. clarify the separtor
#2. deciding on the encoding type
#3. deciding on the encoding column
fixed_df[:3]
# Out:
#             Berri 1  Brébeuf (données non disponibles)  Côte-Sainte-Catherine  \
# Date
# 2012-01-01       35                                NaN                      0
# 2012-01-02       83                                NaN                      1
# 2012-01-03      135                                NaN                      2
#
#             Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  Rachel1  \
# Date
# 2012-01-01             38             51       26            10       16
# 2012-01-02             68            153       53             6       43
# 2012-01-03            104            248       89             3       58
#
#             St-Urbain (données non disponibles)
# Date
# 2012-01-01                                  NaN
# 2012-01-02                                  NaN
# 2012-01-03                                  NaN

# %%
# Selecting various columns
fixed_df["Berri 1"]
# Out:
# Date
# 2012-01-01      35
# 2012-01-02      83
# 2012-01-03     135
# 2012-01-04     144
# 2012-01-05     197
# 2012-01-06     146
# 2012-01-07      98
# 2012-01-08      95
# 2012-01-09     244
# 2012-01-10     397
# 2012-01-11     273
# 2012-01-12     157
# 2012-01-13      75
# 2012-01-14      32
# 2012-01-15      54
# 2012-01-16     168
# 2012-01-17     155
# 2012-01-18     139
# 2012-01-19     191
# 2012-01-20     161
# 2012-01-21      53
# 2012-01-22      71
# 2012-01-23     210
# 2012-01-24     299
# 2012-01-25     334
# 2012-01-26     306
# 2012-01-27      91
# 2012-01-28      80
# 2012-01-29      87
# 2012-01-30     219
#               ...
# 2012-10-07    1580
# 2012-10-08    1854
# 2012-10-09    4787
# 2012-10-10    3115
# 2012-10-11    3746
# 2012-10-12    3169
# 2012-10-13    1783
# 2012-10-14     587
# 2012-10-15    3292
# 2012-10-16    3739
# 2012-10-17    4098
# 2012-10-18    4671
# 2012-10-19    1313
# 2012-10-20    2011
# 2012-10-21    1277
# 2012-10-22    3650
# ...

# %%
# plotting out the graphs
plt.figure(figsize=(15,15))
fixed_df["Berri 1"].plot();

# %%
# Now plotting everything on the same graph
fixed_df.plot(figsize=(15,10));

# %%
# Now plotting the graphs on several subplots 
fixed_df.plot(figsize=(20,40),subplots=True);
plt.legend(loc="best") 
# Then I realized that seperating the plots from each other makes it hard to be comparable
