# %% [markdown]
# The notebook is originally found over here:
# https://www.kaggle.com/kanncaa1/data-sciencetutorial-for-beginners
#
# This is my learning path by going through this notbook. Browsing through the content and it seems to be pretty good

# %% [markdown]
# # Basic Data Science Skills
# 1. Basic Tools. Only need to know ython
# 2. Basic Stats
# 3. Data Wrangling.
# 4. Data Visuzliation
# 5. Machine Learning

# %% [markdown]
# As a summary we will learn python to be data scientist !!!
#
# Content:
#
# 1. Introduction to Python:
# Matplotlib
# Dictionaries
# Pandas
# Logic, control flow and filtering
# Loop data structures
# 2. Python Data Science Toolbox:
# User defined function
# Scope
# Nested function
# Default and flexible arguments
# Lambda function
# Anonymous function
# Iterators
# List comprehension
# 3. Cleaning Data
# Diagnose data for cleaning
# Explotary data analysis
# Visual exploratory data analysis
# Tidy data
# Pivoting data
# Concatenating data
# Data types
# Missing data and testing with assert
# 4. Pandas Foundation
# Review of pandas
# Building data frames from scratch
# Visual exploratory data analysis
# Statistical explatory data analysis
# Indexing pandas time series
# Resampling pandas time series
# 5. Manipulating Data Frames with Pandas
# Indexing data frames
# Slicing data frames
# Filtering data frames
# Transforming data frames
# Index objects and labeled data
# Hierarchical indexing
# Pivoting data frames
# Stacking and unstacking data frames
# Melting data frames
# Categoricals and groupby
# 6. Data Visualization
# Seaborn: https://www.kaggle.com/kanncaa1/seaborn-for-beginners
# Bokeh: https://www.kaggle.com/kanncaa1/interactive-bokeh-tutorial-part-1
# Bokeh: https://www.kaggle.com/kanncaa1/interactive-bokeh-tutorial-part-2
# 7. Machine Learning
# https://www.kaggle.com/kanncaa1/machine-learning-tutorial-for-beginners/

# %%
import numpy as np #linear algebra
import pandas as pd #data processing, csv file IO (Read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
from subprocess import check_output

# %%
print(check_output(["ls","../DS beg"]).decode("utf8"))
# Out:
# combats.csv
# pokemon.csv
# tests.csv

# %%
data=pd.read_csv("../DS beg/pokemon.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          799 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.6+ KB

# %%
#Correlation map
f,ax = plt.subplots(figsize=(18, 18));
sns.heatmap(data.corr(),annot=True,linewidths=.5,fmt= '.1f',ax=ax)

# %%
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          799 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.6+ KB

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# # 1 Intro to Python
# ### Matplotlib

# %%
#Line plot
data.Speed.plot(kind="line",color="g",label="Speed",linewidth=1,alpha=0.3,grid=True,linestyle=":")
data.Defense.plot(kind="line",color='r',label="Defense",linewidth=1,alpha=0.3,grid=True,linestyle="-.")
#The label defined within each function call is linked to the legend call 
plt.legend(loc="upper right")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("Line Plot")
# Out:
# Text(0.5,1,'Line Plot')

# %%
#Scatter Plot
data.plot(kind="scatter",x="Attack",y="Defense",alpha=0.3,color="red")
plt.xlabel("Attack")
plt.ylabel("Defense")
plt.title("Attack Defense Scatter Plot");

# %%
#Histogram
#Bins - number of bars in the figure
data.Speed.plot(kind="hist",bins=50)
plt.title("Speed Distribution of all pokemons")
#If no figsize is defined, then the default is reverted to
# Out:
# Text(0.5,1,'Speed Distribution of all pokemons')

# %%
#clf = cleans it up again you start a fresh 
data.Speed.plot(kind="hist")
plt.clf();

# %% [markdown]
# ### Dictionary

# %%
dictionary = {'spain' : 'madrid','usa' : 'vegas'}
print(dictionary.keys())
print(dictionary.values())
# Out:
# dict_keys(['spain', 'usa'])
# dict_values(['madrid', 'vegas'])

# %%
#Basic Dictionary commands
dictionary["spain"]="barcelona" #updating existing
print(dictionary)
# Out:
# {'spain': 'barcelona', 'usa': 'vegas'}

# %%
dictionary['france']="paris" #adding a new entry
print(dictionary)
# Out:
# {'spain': 'barcelona', 'usa': 'vegas', 'france': 'paris'}

# %%
del dictionary['spain']

# %%
print(dictionary)
print("france" in dictionary) #This is a boolean using dictionary
dictionary.clear()
print(dictionary)
# Out:
# {}
# False
# {}

# %% [markdown]
# ### Pandas

# %%
data=pd.read_csv("../DS beg/pokemon.csv")

# %%
series=data["Defense"] # This retrieves the column as a series
print(type(series))
data_frame=data[["Defense"]] #This retrieves the colomn as a Pandas df
data_frame.head()
print(type(data_frame))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Control flow and logic

# %%
# 1 filtering Pandas data frame
x=data["Defense"]>200
data[x]
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 230  231       Shuckle    Bug    Rock  20      10      230       10      230
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 230      5           2      False
# 333     50           3      False

# %%
# 2 Filtering with logical and by using the numpy logical_and for some reason
data[np.logical_and(data['Defense']>200,data['Attack']>100)]
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 333     50           3      False

# %%
# This is also the same as the np.logical and method using & for filtering
data[(data['Defense']>200) & (data['Attack']>100)]
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 333     50           3      False

# %% [markdown]
# ### While and for loops

# %%
#While loop
i=0
while i!=5:
    print ("i is: ",i)
    i+=1
print("value of i",i , 'is equalt to 5')
# Out:
# i is:  0
# i is:  1
# i is:  2
# i is:  3
# i is:  4
# value of i 5 is equalt to 5

# %%
#For loop
lis=[1,2,3,4,5]
for i in lis:
    print ("i is ",i)
print('')
# Out:
# i is  1
# i is  2
# i is  3
# i is  4
# i is  5

# %%
#Enumerate index and value of list
#index : value = 0:1, 1:2, 2:3, 3:4, 4:5 <-output of enumerate
for index,value in enumerate(lis):
    print(index," : ",value)
print("")
# Out:
# 0  :  1
# 1  :  2
# 2  :  3
# 3  :  4
# 4  :  5

# %%
# For pandas we can achieve index and value
for index,value in data[["Attack"]][0:1].iterrows(): #What does iterrows do?
    print(index," : ", value)
# Out:
# 0  :  Attack    49
# Name: 0, dtype: int64

# %% [markdown]
# # 2 Python Data Science Toolbox
#
# 1. doctrings: documentation for functions
# 2. Tuble: Sequences of immutable python objects (whose values can't be modified). Unpack tuple into several vairables like a,b,c=tuple

# %%
def tuple_ex():
    '''Return defined t tuple'''
    t=(1,2,3)
    return t
a,b,c=tuple_ex()
print(a,b,c)
# Out:
# 1 2 3

# %% [markdown]
# ### Scope
# global: defined main body in script
# local: defined in a function
# built in scope: names in predefined built in scope module such as prnt, len

# %%
x=2
def f():
    x=3
    return x
print(x) #x is global here
print(f()) #x returned is locally defined within the function
# Out:
# 2
# 3

# %%
#When local scope isn't there
x=5
def f():
    y=2*x #There is no local scope for x in the function
    return y
print(f()) #using global x
#First local scope is searched, then global scope searched. If the two
#returns nothing then lastly built in scope is searched
# Out:
# 10

# %%
# How to see what's built in scope
import builtins
len(dir(builtins)) #Number of builtin scopes
# Out:
# 152

# %% [markdown]
# ### Nested Function
# 1. Function within function
# 2. There is a LEGB rule that searches local scope, enclosing function, global and built in scopes

# %%
def square():
    ''' return square of value'''
    def add():
        x=2
        y=3
        z=x+y
        return z
    return add()**2
print(square())
# Out:
# 25

# %% [markdown]
# ### Default and Flexible arguments
# 1. Default arguemnt example:
# def f(a,b=1):
# b=1 is the default arugment
# 2. Flexible argument example:
# def f(*args):
# *arges can be one or more
# 3. Flexible argument example ii:
# def f(**kwargs):
# **kwargs is a dictionary

# %%
# Default arguments
def f(a,b=1,c=2):
    y=a+b+c
    return y
print(f(5)) #This means if the arguments have default values, then 
#the only defined value passed is given to the argument with no default
print(f(5,4))
# Out:
# 8
# 11

# %%
#Flexible arguments *args
def f(*args):
    for i in args:
        print(i)
f(1)
print("")
# Out:
# 1

# %%
f(1,2,3,4,"luck") #Can input as many arguments as desired
# Out:
# 1
# 2
# 3
# 4
# luck

# %%
#Flexible arguments **kwargs notice the double star
def f(**kwargs):
    """print key and value of dictionary"""
    for key, value in kwargs.items():
        print(key," ", value)
f(country = 'spain', capital = 'madrid', population = 123456) #Passing arguments as dictionary
# Out:
# country   spain
# capital   madrid
# population   123456

# %% [markdown]
# ### Lambda Function
# Faster way of writing functions

# %%
#Lambda function
square=lambda x:x**2 #Where x is name of argument
print(square(4))
tot=lambda x,y,z:x+y+z
print(tot(1,2,3))
# Out:
# 16
# 6

# %% [markdown]
# ### Anonymous Function
# Like lambda function but it can take more than one arguments
# map(func,seq): applies a function to all the items in a list

# %%
number_list=[1,2,3]
#Mapping the list through a function, or rather applying function to individually defined items
y=map(lambda x:x**2,number_list)
print(list(y))
# Out:
# [1, 4, 9]

# %% [markdown]
# # Iterators
# 1. Iterable is an object that can return an iterator
# 2. Iterable: an object with an associated iter() method. Exmaple include lists, strings, dictionaries
# 3. Iterator: produces next value with next() method

# %%
#Iteration example
name='ronaldo'
it=iter(name)
print(next(it))
# Out:
# r

# %%
print(next(it))
# Out:
# o

# %%
print(*it)
# Out:
# n a l d o

# %%
#ZIP example
list1=[1,2,3,4]
list2=[5,6,7,8]
z=zip(list1,list2)

# %%
print(z)

# %%
z_list=list(z) #only after converting the ZIP
#object into list is the object viewable through print
type(z)
# Out:
# zip

# %%
print(z_list)
# Out:
# [(1, 5), (2, 6), (3, 7), (4, 8)]

# %%
un_zip=zip(*z_list) #The star operator here seems to reverse what's done
un_list1,un_list2 = list(un_zip) # unzip returns tuble of what happened before

# %%
print(un_list1)
print(un_list2)
print(type(un_list2))
# Out:
# (1, 2, 3, 4)
# (5, 6, 7, 8)
# <class 'tuple'>

# %% [markdown]
# ### List Comprehension
# List comprehension: collapse for loops for building lists into a single line.

# %%
num1=[1,2,3]
num2=[i+1 for i in num1]
print(num2)
# Out:
# [2, 3, 4]

# %%
# Conditionals on iterable
num1=[5,10,15]
num2=[i**2 if i==10 else i-5 if i<7 else i+5 for i in num1]
print(num2)
# Out:
# [0, 100, 20]

# %%
# Lets return pokemon csv and make one more list comprehension example
# Lets classify pokemons whether they have high or low speed. Our threshold is avg speed.
threshold=sum(data.Speed)/len(data.Speed)
#The application of list comprehension in generation of new column is cool
data["speed_level"]=["high" if i > threshold else "low" for i in data.Speed]
data.loc[:10,["speed_level","Speed"]]
# Out:
#    speed_level  Speed
# 0          low     45
# 1          low     60
# 2         high     80
# 3         high     80
# 4          low     65
# 5         high     80
# 6         high    100
# 7         high    100
# 8         high    100
# 9          low     43
# 10         low     58

# %% [markdown]
# # 3. Cleaning Data
# Diagnose data for cleaning
# Unclean data patterns:
# 1. Column inconsistency
# 2. Missing data
# 3. Different language

# %%
data=pd.read_csv("../DS beg/pokemon.csv")
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
data.Generation.value_counts() #There are a lot of ways to do this. Value count is the fastest
# Out:
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: Generation, dtype: int64

# %%
data.tail()
# Out:
#        #            Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  796         Diancie     Rock  Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock  Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic  Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic   Dark  80     160       60      170
# 799  800       Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
data.shape
# Out:
# (800, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          799 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.6+ KB

# %% [markdown]
# ### EXPLOTARY DATA ANALYSIS

# %%
print(data['Type 1'].value_counts(dropna=False))
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ground       32
# Dragon       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
plt.scatter(y=data.Speed.sort_values(),x=np.arange(len(data.Speed)),
           alpha=0.3);

# %%
data.describe()
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %% [markdown]
# ### Visual Exploratory Data Analysis
# Box plots: visualize basic statistics like outliers, min/max quantiles

# %%
data.boxplot(column='Attack',by="Legendary");

#column represent Y values? 
#by represents x values

# %% [markdown]
# ### Tidy Data
# Tidy Data with melt()

# %%
data_new=data.head()
data_new
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
#Applying melt
#id_vars=columns that we don't want to wish to melt
#Value_vars=columns that we want to melt
melted=pd.melt(frame=data_new,id_vars="Name",value_vars=["Attack","Defense"])
melted
# Out:
#             Name variable  value
# 0      Bulbasaur   Attack     49
# 1        Ivysaur   Attack     62
# 2       Venusaur   Attack     82
# 3  Mega Venusaur   Attack    100
# 4     Charmander   Attack     52
# 5      Bulbasaur  Defense     49
# 6        Ivysaur  Defense     63
# 7       Venusaur  Defense     83
# 8  Mega Venusaur  Defense    123
# 9     Charmander  Defense     43

# %% [markdown]
# ### Pivoting Data
# Reverse of melting

# %%
#Index is name
#Want to make the columns are variable
#Finally values in the columns are value
melted.pivot(index="Name",columns='variable',values="value")
# Out:
# variable       Attack  Defense
# Name
# Bulbasaur          49       49
# Charmander         52       43
# Ivysaur            62       63
# Mega Venusaur     100      123
# Venusaur           82       83

# %% [markdown]
# ### Concatenating Data
# Concatenating data

# %%
data1=data.head()
data2=data.tail()
conc_data_row=pd.concat([data1,data2],axis=0,ignore_index=True) # axis=0: 
#adds dataframes vertically
conc_data_row
# Out:
#      #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0    1       Bulbasaur    Grass  Poison  45      49       49       65
# 1    2         Ivysaur    Grass  Poison  60      62       63       80
# 2    3        Venusaur    Grass  Poison  80      82       83      100
# 3    4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4    5      Charmander     Fire     NaN  39      52       43       60
# 5  796         Diancie     Rock   Fairy  50     100      150      100
# 6  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 7  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 8  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 9  800       Volcanion     Fire   Water  80     110      120      130
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# ...

# %%
data1=data["Attack"].head()
data2=data["Defense"].head()
conc_data_col=pd.concat([data1,data2],axis=1) #axis =1, adds data frames horizontally
conc_data_col
# Out:
#    Attack  Defense
# 0      49       49
# 1      62       63
# 2      82       83
# 3     100      123
# 4      52       43

# %% [markdown]
# ### Data Types
# There are 5 basic data types:
# 1. Object(string)
# 2. Bool (binary)
# 3. Integer
# 4. Float
# 5. Categorical
# Why category is import:
# 1. Make dataframes smaller in memory
# 2. Utilized for analysis especially for SKLearn

# %%
list(data.dtypes.unique())
# Out:
# [dtype('int64'), dtype('O'), dtype('bool')]

# %%
# Converting object(str) to categorical and inti to flow
data['Type 1']=data["Type 1"].astype("category")
data["Speed"]=data["Speed"].astype("float")
#Remember the syntax as "astype()"

# %%
data.dtypes
# Out:
# #                int64
# Name            object
# Type 1        category
# Type 2          object
# HP               int64
# Attack           int64
# Defense          int64
# Sp. Atk          int64
# Sp. Def          int64
# Speed          float64
# Generation       int64
# Legendary         bool
# dtype: object

# %% [markdown]
# ### Missing Data and Testing with Assert
# Solutions to missing data:
# 1. Leave as is
# 2. Drop them with dropna()
# 3. Fill missing value with fillna()
# 4. Fill missing values with test stats like mean, medium etc.
# Assert statement:check that you can turn on or off when dong with testing the program

# %%
# Looking at pokemon data that have nan values
#Do this check with the info() call
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          799 non-null object
# Type 1        800 non-null category
# Type 2        414 non-null object
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null float64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), category(1), float64(1), int64(7), object(2)
# memory usage: 64.9+ KB

# %%
# Checking type2
data["Type 2"].value_counts(dropna=False)
# Out:
# NaN         386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Water        14
# Rock         14
# Ghost        14
# Ice          14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: Type 2, dtype: int64

# %%
# Dropping nan values
data1=data
data1["Type 2"].dropna(inplace=True)

# %%
#  Lets check with assert statement
# Assert statement:
assert 1==1 # return nothing because it is true
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-157-853b08a09edd> in <module>()
#       1 #  Lets check with assert statement
#       2 # Assert statement:
# ----> 3 assert 1==2 # return nothing because it is true
#
# AssertionError:

# %%
assert data["Type 2"].notnull().all() #Returns nothing since na has been dropped
# Notnull operator returns row by row boolean values of whether it is null or not
# All method returns whether the entire column is

# %%
data["Type 2"].fillna("empty",inplace=True)

# %%
assert  data['Type 2'].notnull().all() # returns nothing because we drop nan values

# %% [markdown]
# # 4. Pandas Foundation
#
# Single Columns= Series
# NaN=not a number
# dataframe.values=numpy? Not sure what the author means by this
#
# ### Building Data Frames from Scratch
# 1. Build data frames from CSVs
# 2. Build data frames from dictionaries zip() method: This function returns a list of tuples, where the i-th tuple contains the i-th element from each of the argument sequences or iterables.
# 3. Adding New columns
# 4. Broadcasting: create new column and assign value to entire column

# %%
# Data frames from dictionary
country=["Spain","France"]
population=["11","12"]
list_label=["Country","Population"]
list_col=[country,population] #See it here that the inputs are both lists in themselves
zipped=list(zip(list_label,list_col))
data_dict=dict(zipped)
df=pd.DataFrame(data_dict)
df
#To summarize 
# First create individual lists 
# Second make a list of of the lists 
# Third zip the created lists into list of tuples
# Convert the zipped object into dictionaries
# Conver the dictionaries into pandframes
# Out:
#   Country Population
# 0   Spain         11
# 1  France         12

# %%
# Adding new columns 
df["capital"]=["madrid","paris"]
df
# Out:
#   Country Population capital
# 0   Spain         11  madrid
# 1  France         12   paris

# %%
#Broadcasting
df["income"]=0 #Broadcasting so that the entire column is 0
df
# Out:
#   Country Population capital  income
# 0   Spain         11  madrid       0
# 1  France         12   paris       0

# %% [markdown]
# ### Visual Exploratory Data Analysis
# 1. Plot
# 2. Subplot
# 3. Histogram:
# (bins: number of columns, range(tuple): min and max values of columns, normed(boolean): whether the data is normalized or not; cumulative(boolean): compute cumulative distribution)

# %%
data1=data.loc[:,["Attack","Defense","Speed"]]
data1.plot();

# %%
#Making subplots
data1.plot(subplots=True);

# %%
#Scatter plot
data1.plot(kind="scatter",x="Attack",y="Defense") #when the data is already called, no need to refer to the data again in bracket

# %%
plt.scatter(x=data1.Attack, y=data1.Defense,alpha=0.3)
#How come this scatter is different from the scatter above

# %%
# Histogram
data1.plot(kind="hist",y="Defense",bins=50,range=(0,250),normed=True)

# %%
# Histogram
data1.plot(kind="hist",y="Defense",bins=50,range=(0,250),normed=False)
#How come the normed parameter doesn't have any impact at all

# %%
# Histogram subplot with non cumulative and cumulative plotting
