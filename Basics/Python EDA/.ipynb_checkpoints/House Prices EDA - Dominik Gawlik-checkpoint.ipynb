# %% [markdown]
# This is a continuation of the exploration of the real estate data set on python. The key is to explore and become so familiar with the APIs that it becomes a second nature

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import sklearn.linear_model as linear_model
import seaborn as sns
#import xgboost as xgb # <-Couldn't install for a long time tried and tried. May need to come back to this later

# %%
from sklearn.model_selection import KFold
from IPython.display import HTML, display
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# Set up the python data frame display options
pd.options.display.max_rows=1000
pd.options.display.max_columns=20

# %%
fname="../Python EDA/train.csv"
fname1="../Python EDA/test.csv"
train=pd.read_csv(fname)
test=pd.read_csv(fname1)

# %%
#separating the quantitative from the qualittative. These are just column names
quantitative=[f for f in train.columns if train.dtypes[f]!='object']
quantitative.remove('SalePrice')
quantitative.remove('Id')
qualitative=[f for f in train.columns if train.dtypes[f]=='object']

# %%
#Looking at the quantitative and qualitative data sets
print(quantitative)
# Out:
# ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']

# %%
print(qualitative)
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %% [markdown]
# # Missing Data

# %%
missing=train.isnull().sum()
#train.isnull() #<-this returns boolean value on the input dataframe

# %%
missing=missing[missing>0]
missing.sort_values(inplace=True)
missing.plot.bar();

# %%
a=[round(f/len(train),2) for f in missing] #<-this doesn't retain the name of the column
a
# Out:
# [0.0,
#  0.01,
#  0.01,
#  0.03,
#  0.03,
#  0.03,
#  0.03,
#  0.03,
#  0.06,
#  0.06,
#  0.06,
#  0.06,
#  0.06,
#  0.18,
#  0.47,
#  0.81,
#  0.94,
#  0.96,
#  1.0]

# %%
round(missing/len(train),2).plot.bar();

# %% [markdown]
# # Key take away from above:
# 19 attributes have missing values, 5 over 50% of all data. Most of times NA means lack of subject described by attribute, like missing pool, fence, no garage and basement.

# %% [markdown]
# # Qualitative Data

# %%
import scipy.stats as st
#Notice that the fit parameter passed to the sns plot 
#KDE parameter is passed to Whether to plot a gaussian kernel density estimate.
y=train['SalePrice']
plt.figure(1);plt.title("Johnson SU")
sns.distplot(y,kde=False,fit=st.johnsonsu);
plt.figure(2);plt.title("Normal")
sns.distplot(y,kde=False,fit=st.norm);
plt.figure(3);plt.title("LogNormal")
sns.distplot(y,kde=False,fit=st.lognorm);

# %% [markdown]
# It is apparent that SalePrice doesn't follow normal distribution, so before performing regression it has to be transformed. While log transformation does pretty good job, best fit is unbounded Johnson distribution.

# %%
test_normality=lambda x:stats.shapiro(x.fillna(0))[1]<0.01 #stores a lambda function
normal=pd.DataFrame(train[quantitative])

# %%
test_normality
# Out:
# <function __main__.<lambda>>

# %%
normal=normal.apply(test_normality)
normal
# Out:
# MSSubClass       True
# LotFrontage      True
# LotArea          True
# OverallQual      True
# OverallCond      True
# YearBuilt        True
# YearRemodAdd     True
# MasVnrArea       True
# BsmtFinSF1       True
# BsmtFinSF2       True
# BsmtUnfSF        True
# TotalBsmtSF      True
# 1stFlrSF         True
# 2ndFlrSF         True
# LowQualFinSF     True
# GrLivArea        True
# BsmtFullBath     True
# BsmtHalfBath     True
# FullBath         True
# HalfBath         True
# BedroomAbvGr     True
# KitchenAbvGr     True
# TotRmsAbvGrd     True
# Fireplaces       True
# GarageYrBlt      True
# GarageCars       True
# GarageArea       True
# WoodDeckSF       True
# OpenPorchSF      True
# EnclosedPorch    True
# 3SsnPorch        True
# ScreenPorch      True
# PoolArea         True
# MiscVal          True
# MoSold           True
# YrSold           True
# dtype: bool

# %% [markdown]
# Also none of quantitative variables has normal distribution so these should be transformed as well.

# %%
f=pd.melt(train,value_vars=quantitative)
#The melt function turns the wide datatable into a long table

# %%
g=sns.FacetGrid(f,col="variable",col_wrap=3,sharex=False,sharey=False)
g=g.map(sns.distplot,"value")

# %% [markdown]
# Some independent variables look like good candidates for log transformation: TotalBsmtSF, KitchenAbvGr, LotFrontage, LotArea and others. While ganining on regression transformation will smooth out some irregularities which could be important like large amount of houses with 0 2ndFlrSF. Such irregularities are good candidates for feature construction.

# %% [markdown]
# # Categorical data
# with qualitative variables we can implement two methods, first one is to check distribution of SalePrice with respective to variable values and enumerate them. Second to create dummy variable for each possible category

# %%
# First transform them into default category data type
#Second filla the missing values with missing value as a new value category
for c in qualitative: 
    train[c]=train[c].astype("category")
    if train[c].isnull().any():
        train[c]=train[c].cat.add_categories(["MISSING"])
        train[c]=train[c].fillna("MISSING")

# %%
#Define a function to apply all the necessary transformation on the graphs
def boxplot(x,y,**kwargs):
    sns.boxplot(x=x,y=y)
    x=plt.xticks(rotation=90)
#make saleprice the value and the variables the categories
f=pd.melt(train,id_vars=["SalePrice"],value_vars=qualitative)
#Set the grid on top of which the graphs are plotted over
g=sns.FacetGrid(f,col='variable',col_wrap=2,sharex=False,sharey=False,size=5)
#Plot the graphs as box graphs using the mapping function
g=g.map(boxplot,"value","SalePrice")

# %%
f
# Out:
#        SalePrice       variable    value
# 0         208500       MSZoning       RL
# 1         181500       MSZoning       RL
# 2         223500       MSZoning       RL
# 3         140000       MSZoning       RL
# 4         250000       MSZoning       RL
# 5         143000       MSZoning       RL
# 6         307000       MSZoning       RL
# 7         200000       MSZoning       RL
# 8         129900       MSZoning       RM
# 9         118000       MSZoning       RL
# 10        129500       MSZoning       RL
# 11        345000       MSZoning       RL
# 12        144000       MSZoning       RL
# 13        279500       MSZoning       RL
# 14        157000       MSZoning       RL
# 15        132000       MSZoning       RM
# 16        149000       MSZoning       RL
# 17         90000       MSZoning       RL
# 18        159000       MSZoning       RL
# 19        139000       MSZoning       RL
# 20        325300       MSZoning       RL
# 21        139400       MSZoning       RM
# 22        230000       MSZoning       RL
# 23        129900       MSZoning       RM
# 24        154000       MSZoning       RL
# 25        256300       MSZoning       RL
# 26        134800       MSZoning       RL
# 27        306000       MSZoning       RL
# 28        207500       MSZoning       RL
# 29         68500       MSZoning       RM
# 30         40000       MSZoning  C (all)
# 31        149350       MSZoning       RL
# 32        179900       MSZoning       RL
# 33        165500       MSZoning       RL
# 34        277500       MSZoning       RL
# 35        309000       MSZoning       RL
# 36        145000       MSZoning       RL
# 37        153000       MSZoning       RL
# 38        109000       MSZoning       RL
# 39         82000       MSZoning       RL
# 40        160000       MSZoning       RL
# 41        170000       MSZoning       RL
# 42        144000       MSZoning       RL
# 43        130250       MSZoning       RL
# 44        141000       MSZoning       RL
# 45        319900       MSZoning       RL
# 46        239686       MSZoning       RL
# 47        249700       MSZoning       FV
# 48        113000       MSZoning       RM
# 49        127000       MSZoning       RL
# 50        177000       MSZoning       RL
# 51        114500       MSZoning       RM
# 52        110000       MSZoning       RM
# 53        385000       MSZoning       RL
# 54        130000       MSZoning       RL
# 55        180500       MSZoning       RL
# 56        172500       MSZoning       FV
# 57        196500       MSZoning       RL
# 58        438780       MSZoning       RL
# 59        124900       MSZoning       RL
# 60        158000       MSZoning       RL
# 61        101000       MSZoning       RM
# 62        202500       MSZoning       RL
# 63        140000       MSZoning       RM
# 64        219500       MSZoning       RL
# 65        317000       MSZoning       RL
# 66        180000       MSZoning       RL
# 67        226000       MSZoning       RL
# 68         80000       MSZoning       RM
# 69        225000       MSZoning       RL
# 70        244000       MSZoning       RL
# 71        129500       MSZoning       RL
# 72        185000       MSZoning       RL
# 73        144900       MSZoning       RL
# 74        107400       MSZoning       RM
# 75         91000       MSZoning       RM
# 76        135750       MSZoning       RL
# 77        127000       MSZoning       RM
# 78        136500       MSZoning       RL
# 79        110000       MSZoning       RM
# 80        193500       MSZoning       RL
# 81        153500       MSZoning       RM
# 82        245000       MSZoning       RL
# 83        126500       MSZoning       RL
# 84        168500       MSZoning       RL
# 85        260000       MSZoning       RL
# 86        174000       MSZoning       RL
# 87        164500       MSZoning       FV
# 88         85000       MSZoning  C (all)
# 89        123600       MSZoning       RL
# 90        109900       MSZoning       RL
# 91         98600       MSZoning       RL
# 92        163500       MSZoning       RL
# 93        133900       MSZoning  C (all)
# 94        204750       MSZoning       RL
# 95        185000       MSZoning       RL
# 96        214000       MSZoning       RL
# 97         94750       MSZoning       RL
# 98         83000       MSZoning       RL
# 99        128950       MSZoning       RL
# 100       205000       MSZoning       RL
# 101       178000       MSZoning       RL
# 102       118964       MSZoning       RL
# 103       198900       MSZoning       RL
# 104       169500       MSZoning       RM
# 105       250000       MSZoning       FV
# 106       100000       MSZoning       RM
# 107       115000       MSZoning       RM
# 108       115000       MSZoning       RM
# 109       190000       MSZoning       RL
# 110       136900       MSZoning       RL
# 111       180000       MSZoning       RL
# 112       383970       MSZoning       RL
# 113       217000       MSZoning       RL
# 114       259500       MSZoning       RL
# 115       176000       MSZoning       FV
# 116       139000       MSZoning       RL
# 117       155000       MSZoning       RL
# 118       320000       MSZoning       RL
# 119       163990       MSZoning       RL
# 120       180000       MSZoning       RL
# 121       100000       MSZoning       RM
# 122       136000       MSZoning       RL
# 123       153900       MSZoning       RL
# 124       181000       MSZoning       RL
# 125        84500       MSZoning       RM
# 126       128000       MSZoning       RL
# 127        87000       MSZoning       RM
# 128       155000       MSZoning       RL
# 129       150000       MSZoning       RL
# 130       226000       MSZoning       RL
# 131       244000       MSZoning       RL
# 132       150750       MSZoning       RL
# 133       220000       MSZoning       RL
# 134       180000       MSZoning       RL
# 135       174000       MSZoning       RL
# 136       143000       MSZoning       RL
# 137       171000       MSZoning       RL
# 138       230000       MSZoning       RL
# 139       231500       MSZoning       RL
# 140       115000       MSZoning       RL
# 141       260000       MSZoning       RL
# 142       166000       MSZoning       RL
# 143       204000       MSZoning       RL
# 144       125000       MSZoning       RM
# 145       130000       MSZoning       RM
# 146       105000       MSZoning       RM
# 147       222500       MSZoning       RL
# 148       141000       MSZoning       RL
# 149       115000       MSZoning       RM
# 150       122000       MSZoning       RL
# 151       372402       MSZoning       RL
# 152       190000       MSZoning       RL
# 153       235000       MSZoning       RL
# 154       125000       MSZoning       RM
# 155        79000       MSZoning       RL
# 156       109500       MSZoning       RL
# 157       269500       MSZoning       RL
# 158       254900       MSZoning       FV
# 159       320000       MSZoning       RL
# 160       162500       MSZoning       RL
# 161       412500       MSZoning       RL
# 162       220000       MSZoning       RL
# 163       103200       MSZoning       RL
# 164       152000       MSZoning       RM
# 165       127500       MSZoning       RL
# 166       190000       MSZoning       RL
# 167       325624       MSZoning       RL
# 168       183500       MSZoning       RL
# 169       228000       MSZoning       RL
# 170       128500       MSZoning       RM
# 171       215000       MSZoning       RL
# 172       239000       MSZoning       RL
# 173       163000       MSZoning       RL
# 174       184000       MSZoning       RL
# 175       243000       MSZoning       RL
# 176       211000       MSZoning       RL
# 177       172500       MSZoning       RL
# 178       501837       MSZoning       RL
# 179       100000       MSZoning       RM
# 180       177000       MSZoning       FV
# 181       200100       MSZoning       RL
# 182       120000       MSZoning       RL
# 183       200000       MSZoning       RM
# 184       127000       MSZoning       RL
# 185       475000       MSZoning       RM
# 186       173000       MSZoning       RL
# 187       135000       MSZoning       RL
# 188       153337       MSZoning       RL
# 189       286000       MSZoning       RL
# 190       315000       MSZoning       RL
# 191       184000       MSZoning       RL
# 192       192000       MSZoning       RL
# 193       130000       MSZoning       RM
# 194       127000       MSZoning       RL
# 195       148500       MSZoning       RL
# 196       311872       MSZoning       RL
# 197       235000       MSZoning       RL
# 198       104000       MSZoning       RM
# 199       274900       MSZoning       RL
# 200       140000       MSZoning       RM
# 201       171500       MSZoning       RL
# 202       112000       MSZoning       RL
# 203       149000       MSZoning       RM
# 204       110000       MSZoning       RM
# 205       180500       MSZoning       RL
# 206       143900       MSZoning       RL
# 207       141000       MSZoning       RL
# 208       277000       MSZoning       RL
# 209       145000       MSZoning       RL
# 210        98000       MSZoning       RL
# 211       186000       MSZoning       RL
# 212       252678       MSZoning       FV
# 213       156000       MSZoning       RL
# 214       161750       MSZoning       RL
# 215       134450       MSZoning       RL
# 216       210000       MSZoning       RL
# 217       107000       MSZoning       RM
# 218       311500       MSZoning       RL
# 219       167240       MSZoning       RL
# 220       204900       MSZoning       RL
# 221       200000       MSZoning       RL
# 222       179900       MSZoning       RL
# 223        97000       MSZoning       RL
# 224       386250       MSZoning       RL
# 225       112000       MSZoning       RM
# 226       290000       MSZoning       RL
# 227       106000       MSZoning       RM
# 228       125000       MSZoning       RL
# 229       192500       MSZoning       RL
# 230       148000       MSZoning       RL
# 231       403000       MSZoning       RL
# 232        94500       MSZoning       RM
# 233       128200       MSZoning       RL
# 234       216500       MSZoning       RL
# 235        89500       MSZoning       RM
# 236       185500       MSZoning       RL
# 237       194500       MSZoning       RL
# 238       318000       MSZoning       RL
# 239       113000       MSZoning       RL
# 240       262500       MSZoning       FV
# 241       110500       MSZoning       RM
# 242        79000       MSZoning       RM
# 243       120000       MSZoning       RL
# 244       205000       MSZoning       RL
# 245       241500       MSZoning       RL
# 246       137000       MSZoning       RM
# 247       140000       MSZoning       RL
# 248       180000       MSZoning       RL
# 249       277000       MSZoning       RL
# 250        76500       MSZoning       RL
# 251       235000       MSZoning       RM
# 252       173000       MSZoning       RL
# 253       158000       MSZoning       RL
# 254       145000       MSZoning       RL
# 255       230000       MSZoning       RL
# 256       207500       MSZoning       FV
# 257       220000       MSZoning       RL
# 258       231500       MSZoning       RL
# 259        97000       MSZoning       RM
# 260       176000       MSZoning       RL
# 261       276000       MSZoning       RL
# 262       151000       MSZoning       RL
# 263       130000       MSZoning       RM
# 264        73000       MSZoning       RM
# 265       175500       MSZoning       RL
# 266       185000       MSZoning       RL
# 267       179500       MSZoning       RL
# 268       120500       MSZoning       RM
# 269       148000       MSZoning       RL
# 270       266000       MSZoning       FV
# 271       241500       MSZoning       RL
# 272       290000       MSZoning       RL
# 273       139000       MSZoning       RL
# 274       124500       MSZoning       RL
# 275       205000       MSZoning       RL
# 276       201000       MSZoning       RL
# 277       141000       MSZoning       RL
# 278       415298       MSZoning       RL
# 279       192000       MSZoning       RL
# 280       228500       MSZoning       RL
# 281       185000       MSZoning       FV
# 282       207500       MSZoning       RL
# 283       244600       MSZoning       RL
# 284       179200       MSZoning       RL
# 285       164700       MSZoning       FV
# 286       159000       MSZoning       RL
# 287        88000       MSZoning       RL
# 288       122000       MSZoning       RL
# 289       153575       MSZoning       RL
# 290       233230       MSZoning       RL
# 291       135900       MSZoning       RL
# 292       131000       MSZoning       RL
# 293       235000       MSZoning       RL
# 294       167000       MSZoning       RL
# 295       142500       MSZoning       RL
# 296       152000       MSZoning       RM
# 297       239000       MSZoning       FV
# 298       175000       MSZoning       RL
# 299       158500       MSZoning       RL
# 300       157000       MSZoning       RL
# 301       267000       MSZoning       RL
# 302       205000       MSZoning       RL
# 303       149900       MSZoning       RL
# 304       295000       MSZoning       RM
# 305       305900       MSZoning       RL
# 306       225000       MSZoning       RL
# 307        89500       MSZoning       RM
# 308        82500       MSZoning       RL
# 309       360000       MSZoning       RL
# 310       165600       MSZoning       RL
# 311       132000       MSZoning       RL
# 312       119900       MSZoning       RM
# 313       375000       MSZoning       RL
# 314       178000       MSZoning       RM
# 315       188500       MSZoning       RL
# 316       260000       MSZoning       RL
# 317       270000       MSZoning       FV
# 318       260000       MSZoning       RL
# 319       187500       MSZoning       RL
# 320       342643       MSZoning       RL
# 321       354000       MSZoning       RL
# 322       301000       MSZoning       RL
# 323       126175       MSZoning       RM
# 324       242000       MSZoning       RL
# 325        87000       MSZoning       RM
# 326       324000       MSZoning       RL
# 327       145250       MSZoning       RL
# 328       214500       MSZoning       RL
# 329        78000       MSZoning       RM
# 330       119000       MSZoning       RL
# 331       139000       MSZoning       RL
# 332       284000       MSZoning       RL
# 333       207000       MSZoning       RM
# 334       192000       MSZoning       RL
# 335       228950       MSZoning       RL
# 336       377426       MSZoning       RL
# 337       214000       MSZoning       RL
# 338       202500       MSZoning       RL
# 339       155000       MSZoning       RL
# 340       202900       MSZoning       RL
# 341        82000       MSZoning       RH
# 342        87500       MSZoning       RL
# 343       266000       MSZoning       RL
# 344        85000       MSZoning       RM
# 345       140200       MSZoning       RL
# 346       151500       MSZoning       RL
# 347       157500       MSZoning       RL
# 348       154000       MSZoning       RL
# 349       437154       MSZoning       RL
# 350       318061       MSZoning       RL
# 351       190000       MSZoning       RL
# 352        95000       MSZoning       RL
# 353       105900       MSZoning       RM
# 354       140000       MSZoning       RL
# 355       177500       MSZoning       RL
# 356       173000       MSZoning       RL
# 357       134000       MSZoning       RM
# 358       130000       MSZoning       RL
# 359       280000       MSZoning       RL
# 360       156000       MSZoning       RL
# 361       145000       MSZoning       RL
# 362       198500       MSZoning       RL
# 363       118000       MSZoning       RM
# 364       190000       MSZoning       RL
# 365       147000       MSZoning       RM
# 366       159000       MSZoning       RL
# 367       165000       MSZoning       RL
# 368       132000       MSZoning       RL
# 369       162000       MSZoning       RL
# 370       172400       MSZoning       RL
# 371       134432       MSZoning       RL
# 372       125000       MSZoning       RL
# 373       123000       MSZoning       RL
# 374       219500       MSZoning       RL
# 375        61000       MSZoning       RL
# 376       148000       MSZoning       RL
# 377       340000       MSZoning       FV
# 378       394432       MSZoning       RL
# 379       179000       MSZoning       RL
# 380       127000       MSZoning       RL
# 381       187750       MSZoning       FV
# 382       213500       MSZoning       RL
# 383        76000       MSZoning       RH
# 384       240000       MSZoning       RL
# 385       192000       MSZoning       RL
# 386        81000       MSZoning       RL
# 387       125000       MSZoning       RL
# 388       191000       MSZoning       RL
# 389       426000       MSZoning       RL
# 390       119000       MSZoning       RL
# 391       215000       MSZoning       RL
# 392       106500       MSZoning       RL
# 393       100000       MSZoning       RL
# 394       109000       MSZoning       RL
# 395       129000       MSZoning       RL
# 396       123000       MSZoning       RL
# 397       169500       MSZoning       RL
# 398        67000       MSZoning       RM
# 399       241000       MSZoning       FV
# 400       245500       MSZoning       RL
# 401       164990       MSZoning       RL
# 402       108000       MSZoning       RL
# 403       258000       MSZoning       RL
# 404       168000       MSZoning       RL
# 405       150000       MSZoning       RL
# 406       115000       MSZoning       RL
# 407       177000       MSZoning       RL
# 408       280000       MSZoning       RL
# 409       339750       MSZoning       FV
# 410        60000       MSZoning       RL
# 411       145000       MSZoning       RL
# 412       222000       MSZoning       FV
# 413       115000       MSZoning       RM
# 414       228000       MSZoning       RL
# 415       181134       MSZoning       RL
# 416       149500       MSZoning       RL
# 417       239000       MSZoning       RL
# 418       126000       MSZoning       RL
# 419       142000       MSZoning       RL
# 420       206300       MSZoning       RM
# 421       215000       MSZoning       RL
# 422       113000       MSZoning       RL
# 423       315000       MSZoning       RL
# 424       139000       MSZoning       RL
# 425       135000       MSZoning       RM
# 426       275000       MSZoning       RL
# 427       109008       MSZoning       RL
# 428       195400       MSZoning       RL
# 429       175000       MSZoning       RL
# 430        85400       MSZoning       RM
# 431        79900       MSZoning       RM
# 432       122500       MSZoning       RM
# 433       181000       MSZoning       RL
# 434        81000       MSZoning       RM
# 435       212000       MSZoning       RL
# 436       116000       MSZoning       RM
# 437       119000       MSZoning       RM
# 438        90350       MSZoning       RL
# 439       110000       MSZoning       RL
# 440       555000       MSZoning       RL
# 441       118000       MSZoning       RL
# 442       162900       MSZoning       RM
# 443       172500       MSZoning       RL
# 444       210000       MSZoning       RL
# 445       127500       MSZoning       RL
# 446       190000       MSZoning       RL
# 447       199900       MSZoning       RL
# 448       119500       MSZoning       RM
# 449       120000       MSZoning       RM
# 450       110000       MSZoning       RM
# 451       280000       MSZoning       RL
# 452       204000       MSZoning       RL
# 453       210000       MSZoning       FV
# 454       188000       MSZoning       RL
# 455       175500       MSZoning       RL
# 456        98000       MSZoning       RM
# 457       256000       MSZoning       RL
# 458       161000       MSZoning       RM
# 459       110000       MSZoning       RL
# 460       263435       MSZoning       FV
# 461       155000       MSZoning       RL
# 462        62383       MSZoning       RL
# 463       188700       MSZoning       RL
# 464       124000       MSZoning       RL
# 465       178740       MSZoning       RM
# 466       167000       MSZoning       RL
# 467       146500       MSZoning       RL
# 468       250000       MSZoning       RL
# 469       187000       MSZoning       RL
# 470       212000       MSZoning       RL
# 471       190000       MSZoning       RL
# 472       148000       MSZoning       RM
# 473       440000       MSZoning       RL
# 474       251000       MSZoning       RL
# 475       132500       MSZoning       RL
# 476       208900       MSZoning       RL
# 477       380000       MSZoning       RL
# 478       297000       MSZoning       RL
# 479        89471       MSZoning       RM
# 480       326000       MSZoning       RL
# 481       374000       MSZoning       RL
# 482       155000       MSZoning       RM
# 483       164000       MSZoning       RM
# 484       132500       MSZoning       RL
# 485       147000       MSZoning       RL
# 486       156000       MSZoning       RL
# 487       175000       MSZoning       RL
# 488       160000       MSZoning       RL
# 489        86000       MSZoning       RM
# 490       115000       MSZoning       RM
# 491       133000       MSZoning       RL
# 492       172785       MSZoning       RL
# 493       155000       MSZoning       RL
# 494        91300       MSZoning       RM
# 495        34900       MSZoning  C (all)
# 496       430000       MSZoning       RL
# 497       184000       MSZoning       RL
# 498       130000       MSZoning       RL
# 499       120000       MSZoning       RL
# ...          ...            ...      ...
# 62280     116500  SaleCondition   Normal
# 62281     272000  SaleCondition   Normal
# 62282     155000  SaleCondition   Normal
# 62283     239000  SaleCondition   Normal
# 62284     214900  SaleCondition   Normal
# 62285     178900  SaleCondition  Partial
# 62286     160000  SaleCondition   Normal
# 62287     135000  SaleCondition   Normal
# 62288      37900  SaleCondition  Abnorml
# 62289     140000  SaleCondition   Normal
# 62290     135000  SaleCondition  Abnorml
# 62291     173000  SaleCondition   Normal
# 62292      99500  SaleCondition   Normal
# 62293     182000  SaleCondition  Partial
# 62294     167500  SaleCondition   Normal
# 62295     165000  SaleCondition   Normal
# 62296      85500  SaleCondition   Normal
# 62297     199900  SaleCondition  Partial
# 62298     110000  SaleCondition  Abnorml
# 62299     139000  SaleCondition   Normal
# 62300     178400  SaleCondition   Normal
# 62301     336000  SaleCondition   Normal
# 62302     159895  SaleCondition   Normal
# 62303     255900  SaleCondition   Normal
# 62304     126000  SaleCondition   Normal
# 62305     125000  SaleCondition   Normal
# 62306     117000  SaleCondition   Normal
# 62307     395192  SaleCondition  Partial
# 62308     195000  SaleCondition   Normal
# 62309     197000  SaleCondition  Partial
# 62310     348000  SaleCondition   Normal
# 62311     168000  SaleCondition   Normal
# 62312     187000  SaleCondition   Normal
# 62313     173900  SaleCondition  Partial
# 62314     337500  SaleCondition   Normal
# 62315     121600  SaleCondition  Abnorml
# 62316     136500  SaleCondition   Normal
# 62317     185000  SaleCondition   Normal
# 62318      91000  SaleCondition   Normal
# 62319     206000  SaleCondition   Normal
# 62320      82000  SaleCondition   Normal
# 62321      86000  SaleCondition  Abnorml
# 62322     232000  SaleCondition   Normal
# 62323     136905  SaleCondition   Normal
# 62324     181000  SaleCondition   Normal
# 62325     149900  SaleCondition   Normal
# 62326     163500  SaleCondition   Normal
# 62327      88000  SaleCondition   Normal
# 62328     240000  SaleCondition   Normal
# 62329     102000  SaleCondition   Normal
# 62330     135000  SaleCondition   Normal
# 62331     100000  SaleCondition   Normal
# 62332     165000  SaleCondition   Normal
# 62333      85000  SaleCondition   Normal
# 62334     119200  SaleCondition   Normal
# 62335     227000  SaleCondition   Normal
# 62336     203000  SaleCondition   Normal
# 62337     187500  SaleCondition  Abnorml
# 62338     160000  SaleCondition   Normal
# 62339     213490  SaleCondition   Normal
# 62340     176000  SaleCondition   Normal
# 62341     194000  SaleCondition  Partial
# 62342      87000  SaleCondition   Normal
# 62343     191000  SaleCondition   Normal
# 62344     287000  SaleCondition  Abnorml
# 62345     112500  SaleCondition   Normal
# 62346     167500  SaleCondition   Normal
# 62347     293077  SaleCondition  Partial
# 62348     105000  SaleCondition   Normal
# 62349     118000  SaleCondition   Normal
# 62350     160000  SaleCondition   Normal
# 62351     197000  SaleCondition   Normal
# 62352     310000  SaleCondition  Abnorml
# 62353     230000  SaleCondition   Normal
# 62354     119750  SaleCondition   Normal
# 62355      84000  SaleCondition   Normal
# 62356     315500  SaleCondition   Normal
# 62357     287000  SaleCondition   Normal
# 62358      97000  SaleCondition   Normal
# 62359      80000  SaleCondition   Normal
# 62360     155000  SaleCondition   Normal
# 62361     173000  SaleCondition   Normal
# 62362     196000  SaleCondition   Normal
# 62363     262280  SaleCondition   Normal
# 62364     278000  SaleCondition   Normal
# 62365     139600  SaleCondition   Normal
# 62366     556581  SaleCondition  Partial
# 62367     145000  SaleCondition   Normal
# 62368     115000  SaleCondition   Normal
# 62369      84900  SaleCondition  Abnorml
# 62370     176485  SaleCondition  Partial
# 62371     200141  SaleCondition  Partial
# 62372     165000  SaleCondition   Normal
# 62373     144500  SaleCondition   Normal
# 62374     255000  SaleCondition   Normal
# 62375     180000  SaleCondition  Abnorml
# 62376     185850  SaleCondition   Normal
# 62377     248000  SaleCondition   Normal
# 62378     335000  SaleCondition   Normal
# 62379     220000  SaleCondition   Normal
# 62380     213500  SaleCondition   Normal
# 62381      81000  SaleCondition   Normal
# 62382      90000  SaleCondition   Normal
# 62383     110500  SaleCondition   Normal
# 62384     154000  SaleCondition   Normal
# 62385     328000  SaleCondition   Normal
# 62386     178000  SaleCondition   Normal
# 62387     167900  SaleCondition   Normal
# 62388     151400  SaleCondition   Normal
# 62389     135000  SaleCondition   Normal
# 62390     135000  SaleCondition   Normal
# 62391     154000  SaleCondition   Normal
# 62392      91500  SaleCondition   Normal
# 62393     159500  SaleCondition   Normal
# 62394     194000  SaleCondition   Normal
# 62395     219500  SaleCondition   Normal
# 62396     170000  SaleCondition   Normal
# 62397     138800  SaleCondition  Abnorml
# 62398     155900  SaleCondition   Normal
# 62399     126000  SaleCondition   Normal
# 62400     145000  SaleCondition  Abnorml
# 62401     133000  SaleCondition   Normal
# 62402     192000  SaleCondition   Normal
# 62403     160000  SaleCondition   Normal
# 62404     187500  SaleCondition   Normal
# 62405     147000  SaleCondition   Normal
# 62406      83500  SaleCondition   Normal
# 62407     252000  SaleCondition   Normal
# 62408     137500  SaleCondition   Normal
# 62409     197000  SaleCondition   Normal
# 62410      92900  SaleCondition   Normal
# 62411     160000  SaleCondition   Normal
# 62412     136500  SaleCondition   Normal
# 62413     146000  SaleCondition   Normal
# 62414     129000  SaleCondition   Normal
# 62415     176432  SaleCondition   Normal
# 62416     127000  SaleCondition   Normal
# 62417     170000  SaleCondition   Normal
# 62418     128000  SaleCondition   Normal
# 62419     157000  SaleCondition  Abnorml
# 62420      60000  SaleCondition   Normal
# 62421     119500  SaleCondition   Normal
# 62422     135000  SaleCondition   Family
# 62423     159500  SaleCondition   Normal
# 62424     106000  SaleCondition   Normal
# 62425     325000  SaleCondition   Normal
# 62426     179900  SaleCondition   Normal
# 62427     274725  SaleCondition  Partial
# 62428     181000  SaleCondition  Abnorml
# 62429     280000  SaleCondition   Normal
# 62430     188000  SaleCondition   Normal
# 62431     205000  SaleCondition   Normal
# 62432     129900  SaleCondition   Normal
# 62433     134500  SaleCondition   Normal
# 62434     117000  SaleCondition   Normal
# 62435     318000  SaleCondition  Partial
# 62436     184100  SaleCondition   Normal
# 62437     130000  SaleCondition   Normal
# 62438     140000  SaleCondition   Normal
# 62439     133700  SaleCondition   Normal
# 62440     118400  SaleCondition   Normal
# 62441     212900  SaleCondition  Partial
# 62442     112000  SaleCondition  Abnorml
# 62443     118000  SaleCondition   Normal
# 62444     163900  SaleCondition   Normal
# 62445     115000  SaleCondition   Normal
# 62446     174000  SaleCondition   Normal
# 62447     259000  SaleCondition   Family
# 62448     215000  SaleCondition   Normal
# 62449     140000  SaleCondition   Normal
# 62450     135000  SaleCondition   Normal
# 62451      93500  SaleCondition  Abnorml
# 62452     117500  SaleCondition   Normal
# 62453     239500  SaleCondition   Normal
# 62454     169000  SaleCondition   Normal
# 62455     102000  SaleCondition   Normal
# 62456     119000  SaleCondition  Abnorml
# 62457      94000  SaleCondition   Normal
# 62458     196000  SaleCondition   Normal
# 62459     144000  SaleCondition   Normal
# 62460     139000  SaleCondition  Abnorml
# 62461     197500  SaleCondition   Normal
# 62462     424870  SaleCondition  Partial
# 62463      80000  SaleCondition   Normal
# 62464      80000  SaleCondition   Normal
# 62465     149000  SaleCondition   Family
# 62466     180000  SaleCondition   Normal
# 62467     174500  SaleCondition   Normal
# 62468     116900  SaleCondition   Normal
# 62469     143000  SaleCondition   Normal
# 62470     124000  SaleCondition   Normal
# 62471     149900  SaleCondition   Normal
# 62472     230000  SaleCondition  Abnorml
# 62473     120500  SaleCondition   Normal
# 62474     201800  SaleCondition   Normal
# 62475     218000  SaleCondition   Normal
# 62476     179900  SaleCondition   Normal
# 62477     230000  SaleCondition   Normal
# 62478     235128  SaleCondition  Partial
# 62479     185000  SaleCondition   Normal
# 62480     146000  SaleCondition   Normal
# 62481     224000  SaleCondition   Normal
# 62482     129000  SaleCondition   Normal
# 62483     108959  SaleCondition   Alloca
# 62484     194000  SaleCondition   Normal
# 62485     233170  SaleCondition  Partial
# 62486     245350  SaleCondition   Normal
# 62487     173000  SaleCondition   Normal
# 62488     235000  SaleCondition   Normal
# 62489     625000  SaleCondition   Normal
# 62490     171000  SaleCondition   Normal
# 62491     163000  SaleCondition   Normal
# 62492     171900  SaleCondition   Normal
# 62493     200500  SaleCondition   Normal
# 62494     239000  SaleCondition   Normal
# 62495     285000  SaleCondition   Normal
# 62496     119500  SaleCondition   Normal
# 62497     115000  SaleCondition   Normal
# 62498     154900  SaleCondition   Normal
# 62499      93000  SaleCondition   Normal
# 62500     250000  SaleCondition   Normal
# 62501     392500  SaleCondition  Partial
# 62502     745000  SaleCondition  Abnorml
# 62503     120000  SaleCondition   Normal
# 62504     186700  SaleCondition   Normal
# 62505     104900  SaleCondition   Normal
# 62506      95000  SaleCondition  Abnorml
# 62507     262000  SaleCondition   Normal
# 62508     195000  SaleCondition   Normal
# 62509     189000  SaleCondition   Normal
# 62510     168000  SaleCondition   Normal
# 62511     174000  SaleCondition   Normal
# 62512     125000  SaleCondition   Normal
# 62513     165000  SaleCondition   Normal
# 62514     158000  SaleCondition   Normal
# 62515     176000  SaleCondition   Normal
# 62516     219210  SaleCondition  Partial
# 62517     144000  SaleCondition   Normal
# 62518     178000  SaleCondition   Normal
# 62519     148000  SaleCondition   Normal
# 62520     116050  SaleCondition  Abnorml
# 62521     197900  SaleCondition   Normal
# 62522     117000  SaleCondition   Normal
# 62523     213000  SaleCondition   Normal
# 62524     153500  SaleCondition   Normal
# 62525     271900  SaleCondition   Normal
# 62526     107000  SaleCondition   Normal
# 62527     200000  SaleCondition   Normal
# 62528     140000  SaleCondition   Normal
# 62529     290000  SaleCondition  Partial
# 62530     189000  SaleCondition   Normal
# 62531     164000  SaleCondition   Normal
# 62532     113000  SaleCondition   Normal
# 62533     145000  SaleCondition   Normal
# 62534     134500  SaleCondition   Normal
# 62535     125000  SaleCondition   Normal
# 62536     112000  SaleCondition   Normal
# 62537     229456  SaleCondition  Partial
# 62538      80500  SaleCondition   Normal
# 62539      91500  SaleCondition  Abnorml
# 62540     115000  SaleCondition  Abnorml
# 62541     134000  SaleCondition   Normal
# 62542     143000  SaleCondition   Normal
# 62543     137900  SaleCondition   Normal
# 62544     184000  SaleCondition   Normal
# 62545     145000  SaleCondition   Normal
# 62546     214000  SaleCondition   Normal
# 62547     147000  SaleCondition   Normal
# 62548     367294  SaleCondition  Partial
# 62549     127000  SaleCondition   Normal
# 62550     190000  SaleCondition   Normal
# 62551     132500  SaleCondition   Normal
# 62552     101800  SaleCondition   Normal
# 62553     142000  SaleCondition  Abnorml
# 62554     130000  SaleCondition  Abnorml
# 62555     138887  SaleCondition   Normal
# 62556     175500  SaleCondition   Normal
# 62557     195000  SaleCondition   Normal
# 62558     142500  SaleCondition  Abnorml
# 62559     265900  SaleCondition   Normal
# 62560     224900  SaleCondition   Normal
# 62561     248328  SaleCondition  Partial
# 62562     170000  SaleCondition   Family
# 62563     465000  SaleCondition  Partial
# 62564     230000  SaleCondition   Normal
# 62565     178000  SaleCondition  Abnorml
# 62566     186500  SaleCondition  Partial
# 62567     169900  SaleCondition   Normal
# 62568     129500  SaleCondition   Normal
# 62569     119000  SaleCondition   Normal
# 62570     244000  SaleCondition   Normal
# 62571     171750  SaleCondition   Normal
# 62572     130000  SaleCondition   Normal
# 62573     294000  SaleCondition   Normal
# 62574     165400  SaleCondition   Normal
# 62575     127500  SaleCondition   Normal
# 62576     301500  SaleCondition   Normal
# 62577      99900  SaleCondition   Normal
# 62578     190000  SaleCondition   Normal
# 62579     151000  SaleCondition   Normal
# 62580     181000  SaleCondition   Normal
# 62581     128900  SaleCondition   Normal
# 62582     161500  SaleCondition   Normal
# 62583     180500  SaleCondition   Normal
# 62584     181000  SaleCondition  Abnorml
# 62585     183900  SaleCondition   Normal
# 62586     122000  SaleCondition   Normal
# 62587     378500  SaleCondition   Normal
# 62588     381000  SaleCondition   Normal
# 62589     144000  SaleCondition   Normal
# 62590     260000  SaleCondition   Normal
# 62591     185750  SaleCondition   Normal
# 62592     137000  SaleCondition   Normal
# 62593     177000  SaleCondition   Normal
# 62594     139000  SaleCondition   Normal
# 62595     137000  SaleCondition   Normal
# 62596     162000  SaleCondition   Normal
# 62597     197900  SaleCondition   Normal
# 62598     237000  SaleCondition   Normal
# 62599      68400  SaleCondition  Abnorml
# 62600     227000  SaleCondition   Normal
# 62601     180000  SaleCondition   Normal
# 62602     150500  SaleCondition   Normal
# 62603     139000  SaleCondition   Normal
# 62604     169000  SaleCondition   Normal
# 62605     132500  SaleCondition   Normal
# 62606     143000  SaleCondition   Normal
# 62607     190000  SaleCondition   Normal
# 62608     278000  SaleCondition   Normal
# 62609     281000  SaleCondition  Partial
# 62610     180500  SaleCondition   Normal
# 62611     119500  SaleCondition   Normal
# 62612     107500  SaleCondition   Normal
# 62613     162900  SaleCondition   Normal
# 62614     115000  SaleCondition   Normal
# 62615     138500  SaleCondition   Normal
# 62616     155000  SaleCondition   Normal
# 62617     140000  SaleCondition  Partial
# 62618     160000  SaleCondition  Partial
# 62619     154000  SaleCondition   Normal
# 62620     225000  SaleCondition   Normal
# 62621     177500  SaleCondition   Normal
# 62622     290000  SaleCondition   Normal
# 62623     232000  SaleCondition   Normal
# 62624     130000  SaleCondition   Normal
# 62625     325000  SaleCondition   Normal
# 62626     202500  SaleCondition  Partial
# 62627     138000  SaleCondition   Normal
# 62628     147000  SaleCondition   Normal
# 62629     179200  SaleCondition   Normal
# 62630     335000  SaleCondition   Normal
# 62631     203000  SaleCondition  Partial
# 62632     302000  SaleCondition   Normal
# 62633     333168  SaleCondition   Normal
# 62634     119000  SaleCondition   Normal
# 62635     206900  SaleCondition   Normal
# 62636     295493  SaleCondition   Normal
# 62637     208900  SaleCondition  Partial
# 62638     275000  SaleCondition   Normal
# 62639     111000  SaleCondition   Normal
# 62640     156500  SaleCondition   Normal
# 62641      72500  SaleCondition   Normal
# 62642     190000  SaleCondition   Normal
# 62643      82500  SaleCondition   Normal
# 62644     147000  SaleCondition  Partial
# 62645      55000  SaleCondition   Normal
# 62646      79000  SaleCondition   Normal
# 62647     130500  SaleCondition   Normal
# 62648     256000  SaleCondition   Normal
# 62649     176500  SaleCondition   Normal
# 62650     227000  SaleCondition   Normal
# 62651     132500  SaleCondition   Normal
# 62652     100000  SaleCondition   Normal
# 62653     125500  SaleCondition   Normal
# 62654     125000  SaleCondition   Normal
# 62655     167900  SaleCondition   Normal
# 62656     135000  SaleCondition   Normal
# 62657      52500  SaleCondition   Normal
# 62658     200000  SaleCondition   Normal
# 62659     128500  SaleCondition   Normal
# 62660     123000  SaleCondition   Normal
# 62661     155000  SaleCondition   Normal
# 62662     228500  SaleCondition   Normal
# 62663     177000  SaleCondition   Normal
# 62664     155835  SaleCondition  Partial
# 62665     108500  SaleCondition   Normal
# 62666     262500  SaleCondition   Normal
# 62667     283463  SaleCondition  Partial
# 62668     215000  SaleCondition   Normal
# 62669     122000  SaleCondition   Normal
# 62670     200000  SaleCondition   Normal
# 62671     171000  SaleCondition   Normal
# 62672     134900  SaleCondition   Normal
# 62673     410000  SaleCondition   Normal
# 62674     235000  SaleCondition   Normal
# 62675     170000  SaleCondition   Normal
# 62676     110000  SaleCondition   Normal
# 62677     149900  SaleCondition   Normal
# 62678     177500  SaleCondition   Normal
# 62679     315000  SaleCondition   Normal
# 62680     189000  SaleCondition   Normal
# 62681     260000  SaleCondition   Normal
# 62682     104900  SaleCondition   Normal
# 62683     156932  SaleCondition  Partial
# 62684     144152  SaleCondition  Abnorml
# 62685     216000  SaleCondition   Normal
# 62686     193000  SaleCondition  Abnorml
# 62687     127000  SaleCondition   Normal
# 62688     144000  SaleCondition   Normal
# 62689     232000  SaleCondition   Normal
# 62690     105000  SaleCondition   Normal
# 62691     165500  SaleCondition   Normal
# 62692     274300  SaleCondition   Normal
# 62693     466500  SaleCondition   Normal
# 62694     250000  SaleCondition   Normal
# 62695     239000  SaleCondition  Partial
# 62696      91000  SaleCondition   Normal
# 62697     117000  SaleCondition   Normal
# 62698      83000  SaleCondition   Normal
# 62699     167500  SaleCondition   Normal
# 62700      58500  SaleCondition   Normal
# 62701     237500  SaleCondition   Normal
# 62702     157000  SaleCondition   Normal
# 62703     112000  SaleCondition   Normal
# 62704     105000  SaleCondition   Normal
# 62705     125500  SaleCondition   Normal
# 62706     250000  SaleCondition   Normal
# 62707     136000  SaleCondition   Family
# 62708     377500  SaleCondition   Normal
# 62709     131000  SaleCondition   Normal
# 62710     235000  SaleCondition   Normal
# 62711     124000  SaleCondition   Normal
# 62712     123000  SaleCondition   Normal
# 62713     163000  SaleCondition   Normal
# 62714     246578  SaleCondition  Partial
# 62715     281213  SaleCondition   Normal
# 62716     160000  SaleCondition   Normal
# 62717     137500  SaleCondition   Normal
# 62718     138000  SaleCondition   Normal
# 62719     137450  SaleCondition   Normal
# 62720     120000  SaleCondition   Normal
# 62721     193000  SaleCondition   Normal
# 62722     193879  SaleCondition  Partial
# 62723     282922  SaleCondition   Normal
# 62724     105000  SaleCondition   Family
# 62725     275000  SaleCondition   Normal
# 62726     133000  SaleCondition   Normal
# 62727     112000  SaleCondition   Normal
# 62728     125500  SaleCondition   Normal
# 62729     215000  SaleCondition   Normal
# 62730     230000  SaleCondition   Normal
# 62731     140000  SaleCondition   Normal
# 62732      90000  SaleCondition   Normal
# 62733     257000  SaleCondition  Abnorml
# 62734     207000  SaleCondition   Normal
# 62735     175900  SaleCondition   Normal
# 62736     122500  SaleCondition   Normal
# 62737     340000  SaleCondition   Normal
# 62738     124000  SaleCondition   Normal
# 62739     223000  SaleCondition   Normal
# 62740     179900  SaleCondition   Normal
# 62741     127500  SaleCondition   Normal
# 62742     136500  SaleCondition   Normal
# 62743     274970  SaleCondition   Alloca
# 62744     144000  SaleCondition   Normal
# 62745     142000  SaleCondition   Normal
# 62746     271000  SaleCondition   Normal
# 62747     140000  SaleCondition   Normal
# 62748     119000  SaleCondition  Abnorml
# 62749     182900  SaleCondition   Normal
# 62750     192140  SaleCondition   Normal
# 62751     143750  SaleCondition   Normal
# 62752      64500  SaleCondition   Normal
# 62753     186500  SaleCondition   Normal
# 62754     160000  SaleCondition   Normal
# 62755     174000  SaleCondition  Abnorml
# 62756     120500  SaleCondition   Normal
# 62757     394617  SaleCondition  Partial
# 62758     149700  SaleCondition   Normal
# 62759     197000  SaleCondition   Normal
# 62760     191000  SaleCondition   Normal
# 62761     149300  SaleCondition   Normal
# 62762     310000  SaleCondition   Normal
# 62763     121000  SaleCondition   Normal
# 62764     179600  SaleCondition   Normal
# 62765     129000  SaleCondition   Normal
# 62766     157900  SaleCondition   Normal
# 62767     240000  SaleCondition   Normal
# 62768     112000  SaleCondition   Normal
# 62769      92000  SaleCondition  Abnorml
# 62770     136000  SaleCondition   Normal
# 62771     287090  SaleCondition  Partial
# 62772     145000  SaleCondition   Normal
# 62773      84500  SaleCondition  Abnorml
# 62774     185000  SaleCondition   Normal
# 62775     175000  SaleCondition   Normal
# 62776     210000  SaleCondition   Normal
# 62777     266500  SaleCondition   Normal
# 62778     142125  SaleCondition   Normal
# 62779     147500  SaleCondition   Normal
#
# [62780 rows x 3 columns]

# %% [markdown]
# Some categories seem to more diverse with respect to SalePrice than others. Neighborhood has big impact on house prices. Most expensive seems to be Partial SaleCondition. Having pool on property seems to improve price substantially. There are also differences in variabilities between category values.

# %%
def anova(frame):
    anv=pd.DataFrame()
    anv['feature']=qualitative
    pvals=[]
    for c in qualitative:
        samples=[]
        for cls in frame[c].unique():
            s=frame[frame[c]==cls]["SalePrice"].values
            samples.append(s)
        pval=stats.f_oneway(*samples)[1]
        pvals.append(pval)
    anv['pval']=pvals
    return anv.sort_values('pval')

a=anova(train)
a['disparity']=np.log(1./a['pval'].values)
sns.barplot(data=a,x="feature",y="disparity")
x=plt.xticks(rotation=90)

# %%
sns.barplot(data=a,y='pval',x='feature');
x=plt.xticks(rotation=90)

# %% [markdown]
# Here is quick estimation of influence of categorical variable on SalePrice. For each variable SalePrices are partitioned to distinct sets based on category values. Then check with ANOVA test if sets have similar distributions. If variable has minor impact then set means should be equal. Decreasing pval is sign of increasing diversity in partitions.

# %%
def encode(frame, feature):
    ordering = pd.DataFrame()
    ordering['val'] = frame[feature].unique()
    ordering.index = ordering.val
    ordering['spmean'] = frame[[feature, 'SalePrice']].groupby(feature).mean()['SalePrice']
    ordering = ordering.sort_values('spmean')
    ordering['ordering'] = range(1, ordering.shape[0]+1)
    ordering = ordering['ordering'].to_dict()
    
    for cat, o in ordering.items():
        frame.loc[frame[feature] == cat, feature+'_E'] = o
    
qual_encoded = []
for q in qualitative:  
    encode(train, q)
    qual_encoded.append(q+'_E')
print(qual_encoded)
# Out:
# ['MSZoning_E', 'Street_E', 'Alley_E', 'LotShape_E', 'LandContour_E', 'Utilities_E', 'LotConfig_E', 'LandSlope_E', 'Neighborhood_E', 'Condition1_E', 'Condition2_E', 'BldgType_E', 'HouseStyle_E', 'RoofStyle_E', 'RoofMatl_E', 'Exterior1st_E', 'Exterior2nd_E', 'MasVnrType_E', 'ExterQual_E', 'ExterCond_E', 'Foundation_E', 'BsmtQual_E', 'BsmtCond_E', 'BsmtExposure_E', 'BsmtFinType1_E', 'BsmtFinType2_E', 'Heating_E', 'HeatingQC_E', 'CentralAir_E', 'Electrical_E', 'KitchenQual_E', 'Functional_E', 'FireplaceQu_E', 'GarageType_E', 'GarageFinish_E', 'GarageQual_E', 'GarageCond_E', 'PavedDrive_E', 'PoolQC_E', 'Fence_E', 'MiscFeature_E', 'SaleType_E', 'SaleCondition_E']

# %% [markdown]
# # Correlations
# Generally to reduce confunding only variables uncorrelated with each other should be added to regression models (which are correlated with SalePrice).

# %%
#This is to write a function of quickly finding correlations between
#other varialbes and the the saleprice variable 
#Eventually outputting the bar chart of negative and positive correlations 
def spearman(frame,features):
    spr=pd.DataFrame()
    spr['feature']=features
    spr['spearman']=[frame[f].corr(frame['SalePrice'],'spearman') for f in features]
    spr=spr.sort_values("spearman")
    plt.figure(figsize=(6,0.25*len(features)))
    sns.barplot(data=spr,y="feature",x="spearman",orient="h")
    
features=quantitative+qual_encoded
spearman(train,features)

# %% [markdown]
# Spearman correlation is better to work with in this case because it picks up relationships between variables even when they are nonlinear. OverallQual is main criterion in establishing house price. Neighborhood has big influence, partially it has some intrisinc value in itself, but also houses in certain regions tend to share same characteristics (confunding) what causes similar valuations.

# %%
#Looking at the heatmap plotting of the all correlations
plt.figure(1)
corr = train[quantitative+['SalePrice']].corr()
sns.heatmap(corr,cmap="YlGnBu",vmin=-1,vmax=1)
plt.figure(2)
corr = train[qual_encoded+['SalePrice']].corr()
sns.heatmap(corr,cmap="YlGnBu",vmin=-1,vmax=1)
plt.figure(3)
#Still not suare of what the encoded variables mean here
corr = pd.DataFrame(np.zeros([len(quantitative)+1, len(qual_encoded)+1]), index=quantitative+['SalePrice'], columns=qual_encoded+['SalePrice'])
for q1 in quantitative+['SalePrice']:
    for q2 in qual_encoded+['SalePrice']:
        corr.loc[q1, q2] = train[q1].corr(train[q2])
sns.heatmap(corr,cmap="YlGnBu",vmin=-1,vmax=1);

# %% [markdown]
# # pairplots
# it also would be useful to see how sale price compares to each independent variable

# %%
#Again define a function to 
def pairplot(x,y,**kwargs):
    ax=plt.gca()
    ts=pd.DataFrame({'time':x,'val':y})
    ts=ts.groupby("time").mean()
    ts.plot(ax=ax)
    plt.xticks(rotation=90)
    
f=pd.melt(train,id_vars=['SalePrice'],value_vars=quantitative+qual_encoded)
g=sns.FacetGrid(f,col="variable",col_wrap=2,sharex=False,sharey=False,size=5)
g=g.map(pairplot,"value","SalePrice")

# %% [markdown]
# There are lots of nonlinearities this may be the cause why some variables wont be selected by Lasso/Lars. Some factors like YearBuilt, 1stFlrSF, 2ndFlrSF, Neighborhood_E look like they would benefit from adding quadratic term to regression. But on the other hand this will most probably provoke overfit.
